# %% [markdown]
# <a href="https://colab.research.google.com/github/Elpog1/EMSC2010-W2-P2/blob/main/EMSC2010_W2_P2_NB1_u8222275.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EMSC2010_W2_P2_NB1
# ---
#
# *   Class: EMSC2010
# *   Week: 2
# *   Session: Practical 2
#
# ---
#
# From GitHub, you can open this notebook in Google Colab using the 'Open in Colab' button. Then:
#
# 1. Change the notebook name to include your U-number (e.g EMSC2010_W2_P2_NB1_uXXXXXXX.ipynb)
# 2. Save to Google Drive (*File* >>> *Save a copy in Drive*)
# 3. Do a small calculation in a cell (e.g. *1+1*)
# 4. Click *Share* (top right of window)
# 5. Add the **Gmail** address of your partner and send them a notification
#
# Your partner should then open the notebook and:
#
# 6. Do a small calculation in a cell (e.g. *2+2*)
#
# The partner's edits will still be saved in your Google Drive. Once you can see the edits:
#
# 7. Commit to GitHub (*File* >>> *Save a copy in GitHub*)
# 8. Select the repository for your commit (same as your original repository)
# 9. Give a brief commit message (e.g. 'my first test commit')
# 10. Check your GitHub repository, a copy of your notebook should be there.
#
# ---
#
# Because Google Drive is saving your work and the work of your collaborators automatically, you don't need to commit all minor edits to GitHub. Rather commit when you want to archive a version of your notebook because you have completed a substantial task.

# %%
1+1
# Out:
# 2

# %% [markdown]
# Clover Code

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x1 = np.array([1, 3, 7, 12, 25, 89, 68])
y1 = np.array([54, 27, 62, 56, 32, 47, 34])

x2 = np.array([2,4,12,45])
y2 = np.array([45,21,56,22])

# %%
plt.plot(x1, y1,'co-', label='Trial 1') # cyan (c) dots (o) line (-)
plt.plot(x2,y2, 'bo-', label='Trial 2')
plt.xlabel('X')
plt.ylabel('Y')
plt.minorticks_on()
plt.legend()
